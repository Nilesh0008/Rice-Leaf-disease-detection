# %% [markdown]
# ## PRCP-1001-RiceLeaf  & Team Code - PTID-CDS-DEC21-1251 - File no.1

# %% [markdown]
# ### Project introduction

# %% [markdown]
# (Step 1: Identify the business case and categorize the type of the problem to solve)

# %% [markdown]
# ## Problem Statement *
# ### To develop a CNN Model for detection of diseases caused to the Rice Leaf * MultiClass Classification (3 Classes)

# %% [markdown]
# ##There are three classes/diseases:
# * Bacterial leaf blight
# * Brown spot and
# * Leaf smut
#
# *Each having 40,40 and 39 images. The format of all images are jpg.

# %% [markdown]
# # PRIOR RESEARCH

# %% [markdown]
# What is leaf blight disease?
# * Leaf blight disease is caused by the fungus Helminthosporium turcicum Pass. \
# * The disease develops on sorghum leaves particularly under humid conditions by producing reddish-purple or\
# * tan spots that coalesce to form large lesions. It attacks seedlings as well as older plants.

# %% [markdown]
# How to identify leaf Blight ?
# * Water-soaked to yellowish stripes on leaf blades or starting at leaf tips with a wavy margin
# * Leaves with undulated yellowish white or golden yellow marginal necrosis, drying of leaves back from tip and
#     curling, leaving mid rib intact are the major symptoms.

# %% [markdown]
# What is Brown Spot ?
# * Brown spot is a fungal disease that infects the coleoptile, leaves, leaf sheath, panicle branches, glumes, and spikelets. Its most observable damage is the numerous big spots on the leaves which can kill the whole leaf. When infection occurs in the seed, unfilled grains or spotted or discolored seeds are formed.

# %% [markdown]
# What is Leaf Smut ?
#
#  * Leaf smut, caused by the fungus Entyloma oryzae, is a widely distributed, but somewhat minor, disease of rice.

# %% [markdown]
# How to identify Leaf Smut ?
# * Many spots can be found on the same leaf, but the spots remain distinct from each other. Typical symptoms of
# * leaf smut breaks open when wet and releases the black spores. Heavily infected leaves turn yellow, and the leaf tips die and turn gray

# %%
import matplotlib.pyplot as plt

# %%
x=plt.imread('leaf Smut.jpg')
plt.imshow(plt.imread('leaf Smut.jpg',x))
plt.title("Leaf Smut")

# %%
y=plt.imread('Brown spot.jpg')
plt.imshow(plt.imread('Brown Spot.jpg',y))
plt.title("Brown spot")
# Out:
# Text(0.5, 1.0, 'Brown spot')

# %%
z=plt.imread('Bacterial lead Blight.jpg')
plt.imshow(plt.imread('Bacterial Lead blight.jpg',z))
plt.title("Bacterial Lead blight")
# Out:
# Text(0.5, 1.0, 'Bacterial Lead blight')

# %% [markdown]
# ### Summary

# %% [markdown]
# - Step 1- Project - Introduction - The details of the project problem statement, classification higlited in the project introduction sheet - Ref File 1

# %% [markdown]
# Step 2- Data collection, loading - Since the given data has only limited number, additional data images has been augmented.
# The given data has only 40,40,39 data total. First we bifurcated to Train and Valid data.
# Train data we have increasd to 2343 images belonging to 3 classes.
# Valid data we have inreased to 504 images belonging to 3 classes.

# %% [markdown]
# Step 3-  Rename all the dataset to a sequnce number.

# %% [markdown]
# Step 4- Converting Image data into CSV for Visualisation. Even perfomred using PCA and TSNE METHOD.
# From the above plots we can conclude that the data is not sepearable.Dimesionality reduction is also not helping in classification. So, no ML algoirthm works better for classification. Need to try with CNN

# %% [markdown]
# Step 5- Data loading, modeling using CNN, Accuracy plots and Loss plots, and prediction
